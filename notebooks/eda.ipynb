# %%
# Data manipulation
import pandas as pd # data manipulation and dataframes
import numpy as np # arrays manipulation and mathematical operations

# %%
# Pandas configuration
pd.set_option('display.max_columns', None)  # shows all columns
pd.set_option('display.max_colwidth', None)  # shows all cell content

# %%
# Reads csvs
mad_df = pd.read_csv('../data/mad/neighbourhoods.csv', index_col = 0)

# %%
mad_df.sample(20)
# Out:
#                         neighbourhood
# neighbourhood_group
# San Blas - Canillejas         Amposta
# Usera                      San Fermín
# Centro                         Cortes
# Villaverde              San Cristobal
# Tetuán                       Almenara
# Moncloa - Aravaca          El Plantío
# Moratalaz                     Horcajo
# Latina                         Lucero
# Latina                 Cuatro Vientos
# Chamberí                     Arapiles
# Hortaleza               Pinar del Rey
# Chamberí                    Trafalgar
# Villaverde                Los Rosales
# Villaverde                 San Andrés
# Moncloa - Aravaca           Argüelles
# Fuencarral - El Pardo   Fuentelareina
# Tetuán                  Valdeacederas
# Ciudad Lineal             Costillares
# Centro                            Sol
# San Blas - Canillejas      Canillejas
